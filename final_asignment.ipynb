# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (23.0.1)

# %%
# !pip3 install ipykernel==5.5.4
# Out:
# Requirement already satisfied: ipykernel==5.5.4 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (5.5.4)
# Requirement already satisfied: tornado>=4.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipykernel==5.5.4) (6.2)
# Requirement already satisfied: traitlets>=4.1.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipykernel==5.5.4) (5.6.0)
# Requirement already satisfied: ipython>=5.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipykernel==5.5.4) (7.33.0)
# Requirement already satisfied: jupyter-client in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipykernel==5.5.4) (7.4.8)
# Requirement already satisfied: jedi>=0.16 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel==5.5.4) (0.18.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel==5.5.4) (3.0.33)
# Requirement already satisfied: pexpect>4.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel==5.5.4) (4.8.0)
# Requirement already satisfied: pickleshare in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel==5.5.4) (0.7.5)
# Requirement already satisfied: backcall in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel==5.5.4) (0.2.0)
# Requirement already satisfied: decorator in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel==5.5.4) (5.1.1)
# Requirement already satisfied: pygments in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel==5.5.4) (2.13.0)
# Requirement already satisfied: setuptools>=18.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel==5.5.4) (65.5.1)
# Requirement already satisfied: matplotlib-inline in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel==5.5.4) (0.1.6)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-client->ipykernel==5.5.4) (1.5.6)
# Requirement already satisfied: pyzmq>=23.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-client->ipykernel==5.5.4) (24.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-client->ipykernel==5.5.4) (2.8.2)
# Requirement already satisfied: entrypoints in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-client->ipykernel==5.5.4) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-client->ipykernel==5.5.4) (4.12.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel==5.5.4) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from pexpect>4.3->ipython>=5.0.0->ipykernel==5.5.4) (0.7.0)
# Requirement already satisfied: wcwidth in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel==5.5.4) (0.2.5)
# Requirement already satisfied: six>=1.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from python-dateutil>=2.8.2->jupyter-client->ipykernel==5.5.4) (1.16.0)

# %%
# !pip3 install Dash==2.0.0
# !pip3 install jupyter-dash==0.2.0
# Out:
# Requirement already satisfied: Dash==2.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (2.0.0)
# Requirement already satisfied: Flask>=1.0.4 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from Dash==2.0.0) (2.1.3)
# Requirement already satisfied: dash-core-components==2.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from Dash==2.0.0) (2.0.0)
# Requirement already satisfied: plotly>=5.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from Dash==2.0.0) (5.11.0)
# Requirement already satisfied: dash-table==5.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from Dash==2.0.0) (5.0.0)
# Requirement already satisfied: flask-compress in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from Dash==2.0.0) (1.13)
# Requirement already satisfied: dash-html-components==2.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from Dash==2.0.0) (2.0.0)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from Flask>=1.0.4->Dash==2.0.0) (4.11.4)
# Requirement already satisfied: Jinja2>=3.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from Flask>=1.0.4->Dash==2.0.0) (3.1.2)
# Requirement already satisfied: click>=8.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from Flask>=1.0.4->Dash==2.0.0) (8.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from Flask>=1.0.4->Dash==2.0.0) (2.1.2)
# Requirement already satisfied: Werkzeug>=2.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from Flask>=1.0.4->Dash==2.0.0) (2.0.3)
# Requirement already satisfied: tenacity>=6.2.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from plotly>=5.0.0->Dash==2.0.0) (8.1.0)
# Requirement already satisfied: brotli in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from flask-compress->Dash==2.0.0) (1.0.9)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from importlib-metadata>=3.6.0->Flask>=1.0.4->Dash==2.0.0) (4.4.0)
# Requirement already satisfied: zipp>=0.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from importlib-metadata>=3.6.0->Flask>=1.0.4->Dash==2.0.0) (3.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from Jinja2>=3.0->Flask>=1.0.4->Dash==2.0.0) (2.1.1)
# Requirement already satisfied: jupyter-dash==0.2.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (0.2.0)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-dash==0.2.0) (2.28.1)
# Requirement already satisfied: flask in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-dash==0.2.0) (2.1.3)
# Requirement already satisfied: dash in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-dash==0.2.0) (2.0.0)
# Requirement already satisfied: ipykernel in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-dash==0.2.0) (5.5.4)
# Requirement already satisfied: retrying in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-dash==0.2.0) (1.3.3)
# Requirement already satisfied: ansi2html in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-dash==0.2.0) (0.0.0)
# Requirement already satisfied: ipython in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-dash==0.2.0) (7.33.0)
# Requirement already satisfied: importlib-metadata in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ansi2html->jupyter-dash==0.2.0) (4.11.4)
# Requirement already satisfied: dash-core-components==2.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from dash->jupyter-dash==0.2.0) (2.0.0)
# Requirement already satisfied: plotly>=5.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from dash->jupyter-dash==0.2.0) (5.11.0)
# Requirement already satisfied: dash-table==5.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from dash->jupyter-dash==0.2.0) (5.0.0)
# Requirement already satisfied: flask-compress in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from dash->jupyter-dash==0.2.0) (1.13)
# Requirement already satisfied: dash-html-components==2.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from dash->jupyter-dash==0.2.0) (2.0.0)
# Requirement already satisfied: Jinja2>=3.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from flask->jupyter-dash==0.2.0) (3.1.2)
# Requirement already satisfied: click>=8.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from flask->jupyter-dash==0.2.0) (8.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from flask->jupyter-dash==0.2.0) (2.1.2)
# Requirement already satisfied: Werkzeug>=2.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from flask->jupyter-dash==0.2.0) (2.0.3)
# Requirement already satisfied: tornado>=4.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipykernel->jupyter-dash==0.2.0) (6.2)
# Requirement already satisfied: traitlets>=4.1.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipykernel->jupyter-dash==0.2.0) (5.6.0)
# Requirement already satisfied: jupyter-client in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipykernel->jupyter-dash==0.2.0) (7.4.8)
# Requirement already satisfied: jedi>=0.16 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython->jupyter-dash==0.2.0) (0.18.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython->jupyter-dash==0.2.0) (3.0.33)
# Requirement already satisfied: pexpect>4.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython->jupyter-dash==0.2.0) (4.8.0)
# Requirement already satisfied: pickleshare in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython->jupyter-dash==0.2.0) (0.7.5)
# Requirement already satisfied: backcall in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython->jupyter-dash==0.2.0) (0.2.0)
# Requirement already satisfied: decorator in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython->jupyter-dash==0.2.0) (5.1.1)
# Requirement already satisfied: pygments in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython->jupyter-dash==0.2.0) (2.13.0)
# Requirement already satisfied: setuptools>=18.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython->jupyter-dash==0.2.0) (65.5.1)
# Requirement already satisfied: matplotlib-inline in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython->jupyter-dash==0.2.0) (0.1.6)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests->jupyter-dash==0.2.0) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests->jupyter-dash==0.2.0) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests->jupyter-dash==0.2.0) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests->jupyter-dash==0.2.0) (3.4)
# Requirement already satisfied: six>=1.7.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from retrying->jupyter-dash==0.2.0) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from importlib-metadata->ansi2html->jupyter-dash==0.2.0) (4.4.0)
# Requirement already satisfied: zipp>=0.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from importlib-metadata->ansi2html->jupyter-dash==0.2.0) (3.11.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jedi>=0.16->ipython->jupyter-dash==0.2.0) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from Jinja2>=3.0->flask->jupyter-dash==0.2.0) (2.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from pexpect>4.3->ipython->jupyter-dash==0.2.0) (0.7.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from plotly>=5.0.0->dash->jupyter-dash==0.2.0) (8.1.0)
# Requirement already satisfied: wcwidth in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-dash==0.2.0) (0.2.5)
# Requirement already satisfied: brotli in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from flask-compress->dash->jupyter-dash==0.2.0) (1.0.9)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-client->ipykernel->jupyter-dash==0.2.0) (1.5.6)
# Requirement already satisfied: pyzmq>=23.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-client->ipykernel->jupyter-dash==0.2.0) (24.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-client->ipykernel->jupyter-dash==0.2.0) (2.8.2)
# Requirement already satisfied: entrypoints in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-client->ipykernel->jupyter-dash==0.2.0) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-client->ipykernel->jupyter-dash==0.2.0) (4.12.0)

# %%
# !pip install Flask==2.1.3
# Out:
# Requirement already satisfied: Flask==2.1.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (2.1.3)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from Flask==2.1.3) (4.11.4)
# Requirement already satisfied: Jinja2>=3.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from Flask==2.1.3) (3.1.2)
# Requirement already satisfied: click>=8.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from Flask==2.1.3) (8.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from Flask==2.1.3) (2.1.2)
# Requirement already satisfied: Werkzeug>=2.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from Flask==2.1.3) (2.0.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from importlib-metadata>=3.6.0->Flask==2.1.3) (4.4.0)
# Requirement already satisfied: zipp>=0.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from importlib-metadata>=3.6.0->Flask==2.1.3) (3.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from Jinja2>=3.0->Flask==2.1.3) (2.1.1)

# %%
# !pip install -v https://github.com/pallets/werkzeug/archive/refs/tags/2.0.3.tar.gz
# Out:
# Using pip 23.0.1 from /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pip (python 3.7)
# Collecting https://github.com/pallets/werkzeug/archive/refs/tags/2.0.3.tar.gz
#   Using cached https://github.com/pallets/werkzeug/archive/refs/tags/2.0.3.tar.gz
#   Preparing metadata (setup.py) ...   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-kgbqks9s/Werkzeug.egg-info
#   writing /tmp/pip-pip-egg-info-kgbqks9s/Werkzeug.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-kgbqks9s/Werkzeug.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-pip-egg-info-kgbqks9s/Werkzeug.egg-info/requires.txt
#   writing top-level names to /tmp/pip-pip-egg-info-kgbqks9s/Werkzeug.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-kgbqks9s/Werkzeug.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-pip-egg-info-kgbqks9s/Werkzeug.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   no previously-included directories found matching 'docs/_build'
#   warning: no previously-included files matching '*.pyc' found anywhere in distribution
#   adding license file 'LICENSE.rst'
#   writing manifest file '/tmp/pip-pip-egg-info-kgbqks9s/Werkzeug.egg-info/SOURCES.txt'
# done

# %%
# !pip install "jupyterlab>=1.0" jupyterlab-dash==0.1.0a3
# Out:
# Requirement already satisfied: jupyterlab>=1.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (3.6.1)
# Requirement already satisfied: jupyterlab-dash==0.1.0a3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (0.1.0a3)
# Requirement already satisfied: jupyter-server-proxy in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab-dash==0.1.0a3) (3.2.2)
# Requirement already satisfied: dash in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab-dash==0.1.0a3) (2.0.0)
# Requirement already satisfied: jupyter-core in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab>=1.0) (4.12.0)
# Requirement already satisfied: jupyter-server<3,>=1.16.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab>=1.0) (1.23.3)
# Requirement already satisfied: tornado>=6.1.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab>=1.0) (6.2)
# Requirement already satisfied: nbclassic in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab>=1.0) (0.4.8)
# Requirement already satisfied: notebook<7 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab>=1.0) (6.5.2)
# Requirement already satisfied: tomli in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab>=1.0) (2.0.1)
# Requirement already satisfied: jupyter-ydoc~=0.2.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab>=1.0) (0.2.2)
# Requirement already satisfied: jupyter-server-ydoc<0.7.0,>=0.6.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab>=1.0) (0.6.1)
# Requirement already satisfied: jinja2>=2.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab>=1.0) (3.1.2)
# Requirement already satisfied: packaging in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab>=1.0) (21.3)
# Requirement already satisfied: ipython in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab>=1.0) (7.33.0)
# Requirement already satisfied: jupyterlab-server~=2.19 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab>=1.0) (2.19.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jinja2>=2.1->jupyterlab>=1.0) (2.1.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (3.6.2)
# Requirement already satisfied: prometheus-client in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (0.15.0)
# Requirement already satisfied: traitlets>=5.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (5.6.0)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (7.2.6)
# Requirement already satisfied: websocket-client in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (1.4.2)
# Requirement already satisfied: argon2-cffi in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (21.3.0)
# Requirement already satisfied: Send2Trash in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (1.8.0)
# Requirement already satisfied: nbformat>=5.2.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (5.7.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (0.17.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (7.4.8)
# Requirement already satisfied: pyzmq>=17 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (24.0.1)
# Requirement already satisfied: ypy-websocket<0.9.0,>=0.8.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab>=1.0) (0.8.2)
# Requirement already satisfied: jupyter-server-fileid<1,>=0.6.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab>=1.0) (0.8.0)
# Requirement already satisfied: y-py<0.6.0,>=0.5.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-ydoc~=0.2.2->jupyterlab>=1.0) (0.5.9)
# Requirement already satisfied: importlib-metadata>=3.6 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-ydoc~=0.2.2->jupyterlab>=1.0) (4.11.4)
# Requirement already satisfied: jsonschema>=4.17.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab-server~=2.19->jupyterlab>=1.0) (4.17.3)
# Requirement already satisfied: requests>=2.28 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab-server~=2.19->jupyterlab>=1.0) (2.28.1)
# Requirement already satisfied: babel>=2.10 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab-server~=2.19->jupyterlab>=1.0) (2.12.1)
# Requirement already satisfied: json5>=0.9.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab-server~=2.19->jupyterlab>=1.0) (0.9.11)
# Requirement already satisfied: ipython-genutils in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from notebook<7->jupyterlab>=1.0) (0.2.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from notebook<7->jupyterlab>=1.0) (1.5.6)
# Requirement already satisfied: ipykernel in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from notebook<7->jupyterlab>=1.0) (5.5.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbclassic->jupyterlab>=1.0) (0.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from packaging->jupyterlab>=1.0) (3.0.9)
# Requirement already satisfied: Flask>=1.0.4 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from dash->jupyterlab-dash==0.1.0a3) (2.1.3)
# Requirement already satisfied: dash-core-components==2.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from dash->jupyterlab-dash==0.1.0a3) (2.0.0)
# Requirement already satisfied: plotly>=5.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from dash->jupyterlab-dash==0.1.0a3) (5.11.0)
# Requirement already satisfied: dash-table==5.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from dash->jupyterlab-dash==0.1.0a3) (5.0.0)
# Requirement already satisfied: flask-compress in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from dash->jupyterlab-dash==0.1.0a3) (1.13)
# Requirement already satisfied: dash-html-components==2.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from dash->jupyterlab-dash==0.1.0a3) (2.0.0)
# Requirement already satisfied: jedi>=0.16 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython->jupyterlab>=1.0) (0.18.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython->jupyterlab>=1.0) (3.0.33)
# Requirement already satisfied: pexpect>4.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython->jupyterlab>=1.0) (4.8.0)
# Requirement already satisfied: pickleshare in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython->jupyterlab>=1.0) (0.7.5)
# Requirement already satisfied: backcall in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython->jupyterlab>=1.0) (0.2.0)
# Requirement already satisfied: decorator in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython->jupyterlab>=1.0) (5.1.1)
# Requirement already satisfied: pygments in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython->jupyterlab>=1.0) (2.13.0)
# Requirement already satisfied: setuptools>=18.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython->jupyterlab>=1.0) (65.5.1)
# Requirement already satisfied: matplotlib-inline in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython->jupyterlab>=1.0) (0.1.6)
# Requirement already satisfied: aiohttp in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server-proxy->jupyterlab-dash==0.1.0a3) (3.8.4)
# Requirement already satisfied: simpervisor>=0.4 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server-proxy->jupyterlab-dash==0.1.0a3) (0.4)
# Requirement already satisfied: typing-extensions in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (4.4.0)
# Requirement already satisfied: idna>=2.8 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (1.3.0)
# Requirement already satisfied: pytz>=2015.7 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from babel>=2.10->jupyterlab-server~=2.19->jupyterlab>=1.0) (2022.6)
# Requirement already satisfied: click>=8.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from Flask>=1.0.4->dash->jupyterlab-dash==0.1.0a3) (8.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from Flask>=1.0.4->dash->jupyterlab-dash==0.1.0a3) (2.1.2)
# Requirement already satisfied: Werkzeug>=2.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from Flask>=1.0.4->dash->jupyterlab-dash==0.1.0a3) (2.0.3)
# Requirement already satisfied: zipp>=0.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from importlib-metadata>=3.6->jupyter-ydoc~=0.2.2->jupyterlab>=1.0) (3.11.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jedi>=0.16->ipython->jupyterlab>=1.0) (0.8.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab>=1.0) (5.10.1)
# Requirement already satisfied: attrs>=17.4.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab>=1.0) (22.1.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab>=1.0) (1.3.10)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab>=1.0) (0.19.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-client>=6.1.12->jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (2.8.2)
# Requirement already satisfied: entrypoints in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-client>=6.1.12->jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (0.4)
# Requirement already satisfied: jupyter-events>=0.5.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab>=1.0) (0.6.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (1.5.0)
# Requirement already satisfied: nbclient>=0.5.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (0.7.2)
# Requirement already satisfied: jupyterlab-pygments in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (0.2.2)
# Requirement already satisfied: tinycss2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (1.2.1)
# Requirement already satisfied: beautifulsoup4 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (4.11.1)
# Requirement already satisfied: mistune<3,>=2.0.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (2.0.4)
# Requirement already satisfied: defusedxml in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (0.7.1)
# Requirement already satisfied: bleach in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (5.0.1)
# Requirement already satisfied: fastjsonschema in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbformat>=5.2.0->jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (2.16.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from pexpect>4.3->ipython->jupyterlab>=1.0) (0.7.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from plotly>=5.0.0->dash->jupyterlab-dash==0.1.0a3) (8.1.0)
# Requirement already satisfied: wcwidth in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyterlab>=1.0) (0.2.5)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests>=2.28->jupyterlab-server~=2.19->jupyterlab>=1.0) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests>=2.28->jupyterlab-server~=2.19->jupyterlab>=1.0) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests>=2.28->jupyterlab-server~=2.19->jupyterlab>=1.0) (1.26.13)
# Requirement already satisfied: aiosqlite<1,>=0.17.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab>=1.0) (0.18.0)
# Requirement already satisfied: aiofiles<23,>=22.1.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab>=1.0) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from aiohttp->jupyter-server-proxy->jupyterlab-dash==0.1.0a3) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from aiohttp->jupyter-server-proxy->jupyterlab-dash==0.1.0a3) (1.8.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from aiohttp->jupyter-server-proxy->jupyterlab-dash==0.1.0a3) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from aiohttp->jupyter-server-proxy->jupyterlab-dash==0.1.0a3) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from aiohttp->jupyter-server-proxy->jupyterlab-dash==0.1.0a3) (4.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from aiohttp->jupyter-server-proxy->jupyterlab-dash==0.1.0a3) (0.13.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (21.2.0)
# Requirement already satisfied: brotli in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from flask-compress->dash->jupyterlab-dash==0.1.0a3) (1.0.9)
# Requirement already satisfied: rfc3339-validator in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-events>=0.5.0->jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab>=1.0) (0.1.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-events>=0.5.0->jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab>=1.0) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-events>=0.5.0->jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab>=1.0) (6.0)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-events>=0.5.0->jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab>=1.0) (0.1.1)
# Requirement already satisfied: six>=1.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (2.3.2.post1)
# Requirement already satisfied: webencodings in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from bleach->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (0.5.1)
# Requirement already satisfied: pycparser in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab>=1.0) (2.21)
# Requirement already satisfied: isoduration in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab>=1.0) (20.11.0)
# Requirement already satisfied: webcolors>=1.11 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab>=1.0) (1.12)
# Requirement already satisfied: fqdn in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab>=1.0) (1.5.1)
# Requirement already satisfied: jsonpointer>1.13 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab>=1.0) (2.3)
# Requirement already satisfied: uri-template in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab>=1.0) (1.2.0)
# Requirement already satisfied: cached-property>=1.3.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from fqdn->jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab>=1.0) (1.5.2)
# Requirement already satisfied: arrow>=0.15.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from isoduration->jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab>=1.0) (1.2.3)

# %%
# !pip install jupyter_contrib_nbextensions
# Out:
# Requirement already satisfied: jupyter_contrib_nbextensions in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (0.7.0)
# Requirement already satisfied: jupyter-core in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter_contrib_nbextensions) (4.12.0)
# Requirement already satisfied: traitlets>=4.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter_contrib_nbextensions) (5.6.0)
# Requirement already satisfied: jupyter-highlight-selected-word>=0.1.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: ipython-genutils in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: lxml in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter_contrib_nbextensions) (4.9.1)
# Requirement already satisfied: jupyter-contrib-core>=0.3.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter_contrib_nbextensions) (0.4.2)
# Requirement already satisfied: jupyter-nbextensions-configurator>=0.4.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter_contrib_nbextensions) (0.6.1)
# Requirement already satisfied: nbconvert>=6.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter_contrib_nbextensions) (7.2.6)
# Requirement already satisfied: tornado in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter_contrib_nbextensions) (6.2)
# Requirement already satisfied: notebook>=6.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter_contrib_nbextensions) (6.5.2)
# Requirement already satisfied: setuptools in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-contrib-core>=0.3.3->jupyter_contrib_nbextensions) (65.5.1)
# Requirement already satisfied: pyyaml in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.5.0)
# Requirement already satisfied: nbformat>=5.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (5.7.0)
# Requirement already satisfied: importlib-metadata>=3.6 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (4.11.4)
# Requirement already satisfied: jinja2>=3.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.7.2)
# Requirement already satisfied: jupyterlab-pygments in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.2.2)
# Requirement already satisfied: tinycss2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.2.1)
# Requirement already satisfied: beautifulsoup4 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (4.11.1)
# Requirement already satisfied: markupsafe>=2.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.1.1)
# Requirement already satisfied: packaging in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (21.3)
# Requirement already satisfied: mistune<3,>=2.0.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.0.4)
# Requirement already satisfied: defusedxml in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.7.1)
# Requirement already satisfied: pygments>=2.4.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.13.0)
# Requirement already satisfied: bleach in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (5.0.1)
# Requirement already satisfied: prometheus-client in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.15.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (1.8.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.4.8)
# Requirement already satisfied: nest-asyncio>=1.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (1.5.6)
# Requirement already satisfied: ipykernel in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (5.5.4)
# Requirement already satisfied: argon2-cffi in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (21.3.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (7.4.8)
# Requirement already satisfied: terminado>=0.8.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.17.1)
# Requirement already satisfied: pyzmq>=17 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (24.0.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from importlib-metadata>=3.6->nbconvert>=6.0->jupyter_contrib_nbextensions) (4.4.0)
# Requirement already satisfied: zipp>=0.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from importlib-metadata>=3.6->nbconvert>=6.0->jupyter_contrib_nbextensions) (3.11.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-client>=5.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (2.8.2)
# Requirement already satisfied: entrypoints in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-client>=5.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (0.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (1.23.3)
# Requirement already satisfied: fastjsonschema in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (4.17.3)
# Requirement already satisfied: ptyprocess in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from terminado>=0.8.3->notebook>=6.0->jupyter_contrib_nbextensions) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.3.2.post1)
# Requirement already satisfied: webencodings in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from bleach->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from bleach->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.16.0)
# Requirement already satisfied: ipython>=5.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (7.33.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from packaging->nbconvert>=6.0->jupyter_contrib_nbextensions) (3.0.9)
# Requirement already satisfied: jedi>=0.16 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.18.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (3.0.33)
# Requirement already satisfied: pexpect>4.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (4.8.0)
# Requirement already satisfied: pickleshare in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.7.5)
# Requirement already satisfied: backcall in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: decorator in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (5.1.1)
# Requirement already satisfied: matplotlib-inline in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.6)
# Requirement already satisfied: importlib-resources>=1.4.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (5.10.1)
# Requirement already satisfied: attrs>=17.4.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (22.1.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.3.10)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.19.2)
# Requirement already satisfied: anyio<4,>=3.1.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (3.6.2)
# Requirement already satisfied: websocket-client in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (1.4.2)
# Requirement already satisfied: cffi>=1.0.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions) (1.15.1)
# Requirement already satisfied: idna>=2.8 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: pycparser in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.8.3)
# Requirement already satisfied: wcwidth in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.5)

# %%
# !pip install plotly jupyterlab
# Out:
# Requirement already satisfied: plotly in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (5.11.0)
# Requirement already satisfied: jupyterlab in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (3.6.1)
# Requirement already satisfied: tenacity>=6.2.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from plotly) (8.1.0)
# Requirement already satisfied: jupyter-core in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab) (4.12.0)
# Requirement already satisfied: jupyter-server<3,>=1.16.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab) (1.23.3)
# Requirement already satisfied: tornado>=6.1.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab) (6.2)
# Requirement already satisfied: nbclassic in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab) (0.4.8)
# Requirement already satisfied: notebook<7 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab) (6.5.2)
# Requirement already satisfied: tomli in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab) (2.0.1)
# Requirement already satisfied: jupyter-ydoc~=0.2.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab) (0.2.2)
# Requirement already satisfied: jupyter-server-ydoc<0.7.0,>=0.6.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab) (0.6.1)
# Requirement already satisfied: jinja2>=2.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab) (3.1.2)
# Requirement already satisfied: packaging in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab) (21.3)
# Requirement already satisfied: ipython in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab) (7.33.0)
# Requirement already satisfied: jupyterlab-server~=2.19 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab) (2.19.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jinja2>=2.1->jupyterlab) (2.1.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (3.6.2)
# Requirement already satisfied: prometheus-client in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (0.15.0)
# Requirement already satisfied: traitlets>=5.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (5.6.0)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (7.2.6)
# Requirement already satisfied: websocket-client in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (1.4.2)
# Requirement already satisfied: argon2-cffi in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (21.3.0)
# Requirement already satisfied: Send2Trash in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (1.8.0)
# Requirement already satisfied: nbformat>=5.2.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (5.7.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (0.17.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (7.4.8)
# Requirement already satisfied: pyzmq>=17 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (24.0.1)
# Requirement already satisfied: ypy-websocket<0.9.0,>=0.8.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab) (0.8.2)
# Requirement already satisfied: jupyter-server-fileid<1,>=0.6.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab) (0.8.0)
# Requirement already satisfied: y-py<0.6.0,>=0.5.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-ydoc~=0.2.2->jupyterlab) (0.5.9)
# Requirement already satisfied: importlib-metadata>=3.6 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-ydoc~=0.2.2->jupyterlab) (4.11.4)
# Requirement already satisfied: jsonschema>=4.17.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab-server~=2.19->jupyterlab) (4.17.3)
# Requirement already satisfied: requests>=2.28 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab-server~=2.19->jupyterlab) (2.28.1)
# Requirement already satisfied: babel>=2.10 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab-server~=2.19->jupyterlab) (2.12.1)
# Requirement already satisfied: json5>=0.9.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyterlab-server~=2.19->jupyterlab) (0.9.11)
# Requirement already satisfied: ipython-genutils in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from notebook<7->jupyterlab) (0.2.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from notebook<7->jupyterlab) (1.5.6)
# Requirement already satisfied: ipykernel in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from notebook<7->jupyterlab) (5.5.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbclassic->jupyterlab) (0.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from packaging->jupyterlab) (3.0.9)
# Requirement already satisfied: jedi>=0.16 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython->jupyterlab) (0.18.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython->jupyterlab) (3.0.33)
# Requirement already satisfied: pexpect>4.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython->jupyterlab) (4.8.0)
# Requirement already satisfied: pickleshare in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython->jupyterlab) (0.7.5)
# Requirement already satisfied: backcall in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython->jupyterlab) (0.2.0)
# Requirement already satisfied: decorator in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython->jupyterlab) (5.1.1)
# Requirement already satisfied: pygments in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython->jupyterlab) (2.13.0)
# Requirement already satisfied: setuptools>=18.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython->jupyterlab) (65.5.1)
# Requirement already satisfied: matplotlib-inline in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ipython->jupyterlab) (0.1.6)
# Requirement already satisfied: typing-extensions in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab) (4.4.0)
# Requirement already satisfied: idna>=2.8 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab) (1.3.0)
# Requirement already satisfied: pytz>=2015.7 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from babel>=2.10->jupyterlab-server~=2.19->jupyterlab) (2022.6)
# Requirement already satisfied: zipp>=0.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from importlib-metadata>=3.6->jupyter-ydoc~=0.2.2->jupyterlab) (3.11.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jedi>=0.16->ipython->jupyterlab) (0.8.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (5.10.1)
# Requirement already satisfied: attrs>=17.4.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (22.1.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (1.3.10)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (0.19.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-client>=6.1.12->jupyter-server<3,>=1.16.0->jupyterlab) (2.8.2)
# Requirement already satisfied: entrypoints in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-client>=6.1.12->jupyter-server<3,>=1.16.0->jupyterlab) (0.4)
# Requirement already satisfied: jupyter-events>=0.5.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab) (0.6.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (1.5.0)
# Requirement already satisfied: nbclient>=0.5.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (0.7.2)
# Requirement already satisfied: jupyterlab-pygments in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (0.2.2)
# Requirement already satisfied: tinycss2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (1.2.1)
# Requirement already satisfied: beautifulsoup4 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (4.11.1)
# Requirement already satisfied: mistune<3,>=2.0.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (2.0.4)
# Requirement already satisfied: defusedxml in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (0.7.1)
# Requirement already satisfied: bleach in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (5.0.1)
# Requirement already satisfied: fastjsonschema in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from nbformat>=5.2.0->jupyter-server<3,>=1.16.0->jupyterlab) (2.16.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from pexpect>4.3->ipython->jupyterlab) (0.7.0)
# Requirement already satisfied: wcwidth in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyterlab) (0.2.5)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests>=2.28->jupyterlab-server~=2.19->jupyterlab) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests>=2.28->jupyterlab-server~=2.19->jupyterlab) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests>=2.28->jupyterlab-server~=2.19->jupyterlab) (1.26.13)
# Requirement already satisfied: aiosqlite<1,>=0.17.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab) (0.18.0)
# Requirement already satisfied: aiofiles<23,>=22.1.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab) (22.1.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab) (21.2.0)
# Requirement already satisfied: rfc3339-validator in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-events>=0.5.0->jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab) (0.1.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-events>=0.5.0->jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-events>=0.5.0->jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab) (6.0)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jupyter-events>=0.5.0->jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab) (0.1.1)
# Requirement already satisfied: six>=1.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->jupyter-server<3,>=1.16.0->jupyterlab) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (2.3.2.post1)
# Requirement already satisfied: webencodings in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from bleach->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (0.5.1)
# Requirement already satisfied: pycparser in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab) (2.21)
# Requirement already satisfied: isoduration in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (20.11.0)
# Requirement already satisfied: webcolors>=1.11 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (1.12)
# Requirement already satisfied: fqdn in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (1.5.1)
# Requirement already satisfied: jsonpointer>1.13 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (2.3)
# Requirement already satisfied: uri-template in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (1.2.0)
# Requirement already satisfied: cached-property>=1.3.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from fqdn->jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (1.5.2)
# Requirement already satisfied: arrow>=0.15.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from isoduration->jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (1.2.3)

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from pandas) (2022.6)
# Requirement already satisfied: numpy>=1.17.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from pandas) (1.21.6)
# Requirement already satisfied: six>=1.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)

# %%
from jupyter_dash.comms import _send_jupyter_config_comm_request
_send_jupyter_config_comm_request()

# %%
from jupyter_dash import JupyterDash

# %%
import pandas as pd
import dash
from dash import html
from dash import dcc
from dash.dependencies import Input, Output, State
import plotly.graph_objects as go
import plotly.express as px
from dash import no_update

# %%
#Read the airline data
airline_data =  pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/airline_data.csv', 
                            encoding = "ISO-8859-1",
                            dtype={'Div1Airport': str, 'Div1TailNum': str, 
                                   'Div2Airport': str, 'Div2TailNum': str})

# %%
#List of years
year_list = [i for i in range(2005, 2021, 1)]

# %%
def compute_data_choice_1(df):
    #Cancellation Category Count for Bar Chart
    bar_data = df.groupby(['Month','CancellationCode'])['Flights'].sum().reset_index()
    #Average flight time by reporting airline
    line_data = df.groupby(['Month','Reporting_Airline'])['AirTime'].mean().reset_index()
    #Diverted Airport Landings
    div_data = df[df['DivAirportLandings'] != 0.0]
    #Source state count
    map_data = df.groupby(['OriginState'])['Flights'].sum().reset_index()
    #Destination state count
    tree_data = df.groupby(['DestState', 'Reporting_Airline'])['Flights'].sum().reset_index()
    return bar_data, line_data, div_data, map_data, tree_data

def compute_data_choice_2(df):
    #Compute delay average 
    avg_car = df.groupby(['Month','Reporting_Airline'])['CarrierDelay'].mean().reset_index()
    avg_weather = df.groupby(['Month','Reporting_Airline'])['WeatherDelay'].mean().reset_index()
    avg_NAS = df.groupby(['Month','Reporting_Airline'])['NASDelay'].mean().reset_index()
    avg_sec = df.groupby(['Month','Reporting_Airline'])['SecurityDelay'].mean().reset_index()
    avg_late = df.groupby(['Month','Reporting_Airline'])['LateAircraftDelay'].mean().reset_index()
    return avg_car, avg_weather, avg_NAS, avg_sec, avg_late

# %%
#Create dash application and clear the layout until callback executed

app = JupyterDash(__name__)
JupyterDash.infer_jupyter_proxy_config()

#Set the application to show the graphs after callback
app.config.suppress_callback_exceptions = True

# %%
# Application layout
app.layout = html.Div(children=[
                                html.H1('US Domestic Airline Flights Performance', 
                                style={'textAlign': 'center', 'color': '#503D36',
                                'font-size': 24}),
                                
                                #Outer division
                                html.Div([
                                    #Inner division 1
                                    html.Div([
                                        html.Div(
                                            [
                                            html.H2('Report Type:', style={'margin-right': '2em'}),
                                            ]
                                                ),
                                         dcc.Dropdown(id='input-type', 
                                                    options=[
                                                    {'label': 'Yearly Airline Performance Report', 'value': 'OPT1'},
                                                    {'label': 'Yearly Airline Delay Report', 'value': 'OPT2'}
                                                    ],
                                                    placeholder='Select a report type',
                                                    style={'width': '80%', 'padding': '3px', 'font size': '20px', 'text-align-last': 'center'})], 
                                                    style={'display':'flex'}),
                                    
                                    #Inner division 2
                                    html.Div([
                                         html.Div(
                                            [
                                            html.H2('Choose Year:', style={'margin-right': '2em'}),
                                            ]
                                                ),
                                        dcc.Dropdown(id='input-year', 
                                                     # Update dropdown values using list comphrehension
                                                     options=[{'label': i, 'value': i} for i in year_list],
                                                     placeholder="Select a year",
                                                     style={'width':'80%', 'padding':'3px', 'font-size': '20px', 'text-align-last' : 'center'}),
                                            # Place them next to each other using the division style
                                            ], style={'display': 'flex'}),  
                                          ]),
                                
                                # Add computer graphs to be updated during callback
                                #1st division
                                html.Div([ ], id='plot1'),
                                #2nd division
                                html.Div([
                                        html.Div([ ], id='plot2'),
                                        html.Div([ ], id='plot3')
                                ], style={'display': 'flex'}),
                                #3rd division
                                html.Div([
                                        html.Div([ ], id='plot4'),
                                        html.Div([ ], id='plot5')
                                ], style={'display': 'flex'})])

#Create the callback

@app.callback([Output(component_id='plot1', component_property='children'),
               Output(component_id='plot2', component_property='children'),
               Output(component_id='plot3', component_property='children'),
               Output(component_id='plot4', component_property='children'),
               Output(component_id='plot5', component_property='children')],
              [Input(component_id='input-type', component_property='value'),
               Input(component_id='input-year', component_property='value')],
               #Holding output state till user enters all the form information (type of chart and year)
              [State("plot1", 'children'), State("plot2", "children"),
               State("plot3", "children"), State("plot4", "children"),
               State("plot5", "children")
              ])



# Add computation to callback function and return graph
def get_graph(chart, year, children1, children2, c3, c4, c5):
      
        # Select data
        df =  airline_data[airline_data['Year']== year]
       
        if chart == 'OPT1':
            # Compute required information for creating graph from the data
            bar_data, line_data, div_data, map_data, tree_data = compute_data_choice_1(df)
            
            # Number of flights under different cancellation categories
            bar_fig = px.bar(bar_data, x='Month', y='Flights', color='CancellationCode', title='Monthly Flight Cancellation')
            
            # Average flight time by reporting airline
            line_fig = px.line(line_data, x ='Month', y='AirTime', color = 'Reporting_Airline', title = 'Average monthly flight time (minutes) by airline.')
            
            # Percentage of diverted airport landings per reporting airline
            pie_fig = px.pie(div_data, values='Flights', names='Reporting_Airline', title='% of flights by reporting airline')
            
            # Number of flights flying from each state using choropleth
            map_fig = px.choropleth(map_data,  # Input data
                    locations='OriginState', 
                    color='Flights',  
                    hover_data=['OriginState', 'Flights'], 
                    locationmode = 'USA-states', # Set to plot as US States
                    color_continuous_scale='GnBu',
                    range_color=[0, map_data['Flights'].max()]) 
            map_fig.update_layout(
                    title_text = 'Number of flights from origin state', 
                    geo_scope='usa') # Plot only the USA instead of globe
            
            # Number of flights flying to each state from each reporting airline
            tree_fig = px.treemap(tree_data, path=['DestState', 'Reporting_Airline'], 
                      values='Flights',
                      color='Reporting_Airline',
                      color_continuous_scale='RdBu',
                      title='Flight count by airline to destination state'
                )
            return [dcc.Graph(figure=tree_fig), 
                    dcc.Graph(figure=pie_fig),
                    dcc.Graph(figure=map_fig),
                    dcc.Graph(figure=bar_fig),
                    dcc.Graph(figure=line_fig)
                   ]
            
        else:
            # Charts under "Flight Delay Time Statistics Dashboard" section
            # Compute required information for creating graph from the data
            avg_car, avg_weather, avg_NAS, avg_sec, avg_late = compute_data_choice_2(df)
            
            # Create graph
            carrier_fig = px.line(avg_car, x='Month', y='CarrierDelay', color='Reporting_Airline', title='Average carrrier delay time (minutes) by airline')
            weather_fig = px.line(avg_weather, x='Month', y='WeatherDelay', color='Reporting_Airline', title='Average weather delay time (minutes) by airline')
            nas_fig = px.line(avg_NAS, x='Month', y='NASDelay', color='Reporting_Airline', title='Average NAS delay time (minutes) by airline')
            sec_fig = px.line(avg_sec, x='Month', y='SecurityDelay', color='Reporting_Airline', title='Average security delay time (minutes) by airline')
            late_fig = px.line(avg_late, x='Month', y='LateAircraftDelay', color='Reporting_Airline', title='Average late aircraft delay time (minutes) by airline')
            
            return[dcc.Graph(figure=carrier_fig), 
                   dcc.Graph(figure=weather_fig), 
                   dcc.Graph(figure=nas_fig), 
                   dcc.Graph(figure=sec_fig), 
                   dcc.Graph(figure=late_fig)]
        
# Run the app
if __name__ == '__main__':
    app.run_server(mode="external", host="localhost", port="13588", debug=False, dev_tools_ui=False, dev_tools_props_check=False)
# Out:
# 127.0.0.1 - - [01/Mar/2023 10:47:34] "GET /_shutdown_484ad01c-cfbc-42cb-96c9-7800fbb72f02 HTTP/1.1" 200 -
#  * Running on http://localhost:13588/ (Press CTRL+C to quit)
# 127.0.0.1 - - [01/Mar/2023 10:47:34] "GET /_alive_484ad01c-cfbc-42cb-96c9-7800fbb72f02 HTTP/1.1" 200 -
# Dash app running on https://jupyterlab-4-labs-prod-jupyterlab-us-east-0.labs.cognitiveclass.ai/user/renupanchal2/proxy/13588/
# 127.0.0.1 - - [01/Mar/2023 10:47:42] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2023 10:47:44] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2023 10:47:44] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2023 10:47:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2023 10:47:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2023 10:47:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2023 10:48:59] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2023 10:49:00] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2023 10:49:00] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2023 10:49:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2023 11:02:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2023 11:02:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2023 11:32:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2023 11:33:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2023 11:33:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2023 11:34:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2023 11:34:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2023 11:34:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2023 11:34:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2023 11:35:18] "POST /_dash-update-component HTTP/1.1" 200 -
